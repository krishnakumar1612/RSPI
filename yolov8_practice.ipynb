# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# array-record                  0.2.0
# arviz                         0.15.1
# astropy                       5.2.2
# astunparse                    1.6.3
# attrs                         23.1.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# blosc2                        2.0.0
# bokeh                         2.4.3
# branca                        0.6.0
# ...

# %%
pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.5/584.5 kB 28.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 21.9 MB/s eta 0:00:00
# ...

# %%
ultralytics-8.0.99

# %%
from ultralytics import YOLO

# %%
# # Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 246MB/s]

# %%
results = model(['https://ultralytics.com/images/bus.jpg', 'https://ultralytics.com/images/bus.jpg'])
# Out:
# 0: 640x480 4 persons, 1 bus, 1 stop sign, 1: 640x480 4 persons, 1 bus, 1 stop sign, 508.4ms
# Speed: 22.2ms preprocess, 254.2ms inference, 16.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
results
# Out:
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
# save images with results
# resize to 320 x 320,so the of image to model is (1, 3, 320, 320)
model.predict('https://ultralytics.com/images/bus.jpg', save=True, imgsz=320, conf=0.5)
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 56.6MB/s]
# image 1/1 /content/bus.jpg: 320x256 3 persons, 1 bus, 55.1ms
# Speed: 1.3ms preprocess, 55.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
dir(results[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_keys',
#  'boxes',
#  'cpu',
#  'cuda',
#  'keypoints',
#  'keys',
#  'masks',
#  'names',
#  'new',
#  'numpy',
#  'orig_img',
#  'orig_shape',
#  'pandas',
#  'path',
#  'plot',
#  'probs',
#  'save_crop',
#  'save_txt',
#  'speed',
#  'to',
#  'tojson',
#  'update',
#  'verbose']

# %%
print(results[0].tojson())
# Out:
# [
#   {
#     "name": "bus",
#     "class": 5,
#     "confidence": 0.8703799843788147,
#     "box": {
#       "x1": 17.44441795349121,
#       "y1": 230.729736328125,
#       "x2": 801.0457763671875,
#       "y2": 768.98291015625
#     }
#   },
#   {
#     "name": "person",
#     "class": 0,
#     "confidence": 0.8689174652099609,
#     "box": {
#       "x1": 48.757080078125,
#       "y1": 399.2707214355469,
#       "x2": 244.4107666015625,
#       "y2": 902.5100708007812
#     }
#   },
#   {
#     "name": "person",
#     "class": 0,
#     "confidence": 0.8526697754859924,
#     "box": {
#       "x1": 670.3557739257812,
#       "y1": 379.8884582519531,
#       "x2": 809.8599243164062,
#       "y2": 875.491943359375
#     }
#   },
#   {
#     "name": "person",
#     "class": 0,
#     "confidence": 0.8186339735984802,
#     "box": {
#       "x1": 221.34249877929688,
#       "y1": 405.78875732421875,
#       "x2": 344.8335266113281,
#       "y2": 857.4578247070312
#     }
#   },
#   {
# ...

# %%
results[0].keys
# Out:
# ['boxes']

# %%
results[0].boxes
# Out:
# WARNING ⚠️ 'Boxes.boxes' is deprecated. Use 'Boxes.data' instead.
# ultralytics.yolo.engine.results.Boxes object with attributes:
#
# boxes: tensor([[1.7444e+01, 2.3073e+02, 8.0105e+02, 7.6898e+02, 8.7038e-01, 5.0000e+00],
#         [4.8757e+01, 3.9927e+02, 2.4441e+02, 9.0251e+02, 8.6892e-01, 0.0000e+00],
#         [6.7036e+02, 3.7989e+02, 8.0986e+02, 8.7549e+02, 8.5267e-01, 0.0000e+00],
#         [2.2134e+02, 4.0579e+02, 3.4483e+02, 8.5746e+02, 8.1863e-01, 0.0000e+00],
#         [7.1525e-02, 2.5481e+02, 3.2148e+01, 3.2499e+02, 3.4761e-01, 1.1000e+01],
#         [0.0000e+00, 5.5082e+02, 6.7111e+01, 8.7390e+02, 2.8189e-01, 0.0000e+00]])
# cls: tensor([ 5.,  0.,  0.,  0., 11.,  0.])
# conf: tensor([0.8704, 0.8689, 0.8527, 0.8186, 0.3476, 0.2819])
# data: tensor([[1.7444e+01, 2.3073e+02, 8.0105e+02, 7.6898e+02, 8.7038e-01, 5.0000e+00],
#         [4.8757e+01, 3.9927e+02, 2.4441e+02, 9.0251e+02, 8.6892e-01, 0.0000e+00],
# ...

# %%
r1 = results[0].probs
r1

# %%
print(r1)
# Out:
# None

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow( results[0].plot())
# Out:
# <PIL.Image.Image image mode=RGB size=810x1080 at 0x7F3FADB7E950>

# %%
# detected object class
results[0].boxes.cls.numpy()
# Out:
# array([          5,           0,           0,           0,          11,           0], dtype=float32)

# %%
import numpy as np

# %%
unique, counts = np.unique(results[0].boxes.cls.numpy(), return_counts=True)

# %%
dict(zip(counts, unique ))
# Out:
# {4: 0.0, 1: 11.0}

# %%
unique.dtype
# Out:
# dtype('float32')

# %%
unique
# Out:
# array([          0,           5,          11], dtype=float32)

# %%
counts
# Out:
# array([4, 1, 1])

# %%
dict(zip( unique , counts))
# Out:
# {0: 4, 5: 1, 11: 1}

# %%
unique = unique.astype(np.uint8)

# %%
counts.dtype
# Out:
# dtype('int64')

# %%
results[0].names.get(0)
# Out:
# 'person'

# %%
for result in results :
  print(f"Detections for image {result.boxes.conf} : ")
  for k, v in dict(zip(unique , counts)).items() :
    clsname = result.names.get(k)
    print(f"{v} {clsname} detected")
  print()
# Out:
# Detections for image tensor([0.8704, 0.8689, 0.8527, 0.8186, 0.3476, 0.2819]) :
# 4 person detected
# 1 bus detected
# 1 stop sign detected
#
# Detections for image tensor([0.8704, 0.8689, 0.8527, 0.8186, 0.3476, 0.2819]) :
# 4 person detected
# 1 bus detected
# 1 stop sign detected

# %% [markdown]
# need images in yolo format
# need to train model - last layer, pev to last layer

# %%
results = model.predict('/content/download.jpeg', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/download.jpeg: 320x320 1 bottle, 93.6ms
# Speed: 5.2ms preprocess, 93.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict

# %%
# /content/runs/detect/predict/download.jpeg
